# %%
import pandas as pd

# %%
# Load the data
purchase_orders = pd.read_excel('erp_data/tabPurchase Order.xlsx')
purchase_order_items = pd.read_excel('erp_data/tabPurchase Order Item.xlsx')
purchase_receipts = pd.read_excel('erp_data/tabPurchase Receipt.xlsx')
purchase_receipt_items = pd.read_excel('erp_data/tabPurchase Receipt Item.xlsx')

# %%
# Join the data
flattable = pd.merge(
    purchase_orders, 
    purchase_order_items, 
    how='left',
    left_on = 'name',
    right_on = 'parent',
    suffixes = ('_po', '_po_items')
    )

# %%
flattable = pd.merge( 
    flattable, 
    purchase_receipt_items, 
    how='left',
    left_on = 'name_po',
    right_on = 'purchase_order',
    suffixes = ('', '_receipt_items')
    )

# %%
flattable = pd.merge( 
        flattable, 
        purchase_receipts, 
        how='left',
        left_on = 'parent_receipt_items',
        right_on = 'name',
        suffixes = ('', '_receipt')
        )

# %%
flattable.head()
# Out:
#                  name_po             creation_po             modified_po  \
# 0  PUR-ORD-2024-08-00001 2024-08-01 10:17:46.107 2024-08-01 10:17:47.230
# 1  PUR-ORD-2024-08-00002 2024-08-01 10:36:25.678 2024-08-01 10:36:26.333
# 2  PUR-ORD-2024-08-00003 2024-08-01 10:36:26.723 2024-08-01 10:36:26.723
# 3  PUR-ORD-2024-08-00004 2024-08-01 10:36:27.026 2024-08-01 10:36:27.629
# 4  PUR-ORD-2024-08-00005 2024-08-01 10:36:28.088 2024-08-01 10:36:28.684
#
#   modified_by_po       owner_po  docstatus_po  idx_po            title  \
# 0  Administrator  Administrator             1       2  {supplier_name}
# 1  Administrator  Administrator             1       2  {supplier_name}
# 2  Administrator  Administrator             1       0  {supplier_name}
# 3  Administrator  Administrator             1       2  {supplier_name}
# 4  Administrator  Administrator             1       2  {supplier_name}
#
#           naming_series       supplier  ... represents_company_receipt  \
# ...
